# %%
import numpy as np
import pandas as pd
import warnings
import graphviz
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns

from sklearn import datasets
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, export_graphviz
from sklearn.model_selection import  train_test_split
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, classification_report
)

# %%
df_plasma = pd.read_excel(r"C:\Users\a.v.nasirov\Desktop\UDGU_project\random_tree_Tremor\Vse_dannye_BP_Tremor_1_unian_data.xlsx",sheet_name="ФРАКЦИИ плазма")

# %%
df_plasma = df_plasma.drop("ФИО",axis=1)
df_plasma = df_plasma.drop("№",axis=1)

# %%
df_plasma
# Out:
#        ЭХ     ТГ   НеЖК     ХЛ     ФЛ  здоров(1)\болен(0)
# 0   18.50  22.14  40.32   9.92   9.12                   0
# 1   13.86  28.41  35.16  11.68  10.89                   0
# 2   11.44  22.15  41.55  15.75   9.11                   0
# 3   16.61  17.60  47.41   8.68   9.70                   0
# 4   17.11  38.29  11.49  18.14  14.97                   0
# ..    ...    ...    ...    ...    ...                 ...
# 80  16.00  25.03  31.46  18.69   8.82                   1
# 81  18.77  15.33  32.85  16.19  16.86                   1
# 82  11.09  33.36  28.70  13.95  12.90                   1
# 83  17.93  24.84  30.54  14.14  12.55                   1
# 84  16.70  25.98  33.38  10.56  13.38                   1
#
# [85 rows x 6 columns]

# %%
x = df_plasma.drop("здоров(1)\болен(0)", axis = 1)
y = df_plasma["здоров(1)\болен(0)"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y)

# %%
clf = RandomForestClassifier(n_estimators=150,random_state = 42,class_weight= {0: 1, 1: 8},max_depth = 3)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
accuracy_score(y_pred, y_test)
print(f"Accuracy:{accuracy_score(y_test, y_pred):.3f}")
print(f"Precision:{precision_score(y_test, y_pred):.3f}")
print(f"Recall:  {recall_score(y_test, y_pred):.3f}")
print(f"F1-score: {f1_score(y_test, y_pred):.3f}")
# print(f"ROC-AUC:{roc_auc_score(y_test, y_proba):.3f}")
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy:0.923
# Precision:1.000
# Recall:  0.500
# F1-score: 0.667
#
# Confusion Matrix:
#  [[22  0]
#  [ 2  2]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        22
#            1       1.00      0.50      0.67         4
#
#     accuracy                           0.92        26
#    macro avg       0.96      0.75      0.81        26
# weighted avg       0.93      0.92      0.91        26

# %%
from sklearn.model_selection import cross_val_score


scores_f1 = cross_val_score(clf, x, y, cv=5, scoring='f1')

print(f"F1-результаты по фолдам: {scores_f1}")
print(f"Средний F1: {scores_f1.mean():.2f}")
# Out:
# F1-результаты по фолдам: [0.  0.4 0.5 0.  0. ]
# Средний F1: 0.18

# %%
from sklearn.ensemble import GradientBoostingClassifier

clf = GradientBoostingClassifier(
    n_estimators=120,
    max_depth=3,
    random_state=42
)

# Создаем веса для каждой строки обучающей выборки
weights = y_train.map({0:1, 1:6})

clf.fit(x_train, y_train, sample_weight=weights)
y_pred = clf.predict(x_test)
accuracy_score(y_pred, y_test)
# Out:
# 0.9230769230769231

# %%
print(f"Accuracy:{accuracy_score(y_test, y_pred):.3f}")
print(f"Precision:{precision_score(y_test, y_pred):.3f}")
print(f"Recall:  {recall_score(y_test, y_pred):.3f}")
print(f"F1-score: {f1_score(y_test, y_pred):.3f}")
# print(f"ROC-AUC:{roc_auc_score(y_test, y_proba):.3f}")
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy:0.923
# Precision:1.000
# Recall:  0.500
# F1-score: 0.667
#
# Confusion Matrix:
#  [[22  0]
#  [ 2  2]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        22
#            1       1.00      0.50      0.67         4
#
#     accuracy                           0.92        26
#    macro avg       0.96      0.75      0.81        26
# weighted avg       0.93      0.92      0.91        26

# %%
from sklearn.model_selection import cross_val_score


scores_f1 = cross_val_score(clf, x, y, cv=5, scoring='f1')

print(f"F1-результаты по фолдам: {scores_f1}")
print(f"Средний F1: {scores_f1.mean():.2f}")
# Out:
# F1-результаты по фолдам: [0.         0.66666667 0.66666667 0.         0.        ]
# Средний F1: 0.27
