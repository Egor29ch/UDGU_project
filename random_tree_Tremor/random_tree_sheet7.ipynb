# %%
import numpy as np
import pandas as pd
import warnings
import graphviz
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns

from sklearn import datasets
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, export_graphviz
from sklearn.model_selection import  train_test_split
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, classification_report
)

# %%
df_sheet7 = pd.read_excel(r"C:\Users\a.v.nasirov\Desktop\UDGU_project\random_tree_Tremor\Vse_dannye_BP_Tremor_1_unian_data.xlsx",sheet_name="Лист7")

# %%
df_sheet7 = df_sheet7.drop("ФИО",axis=1)
df_sheet7 = df_sheet7.drop("№",axis=1)

# %%
df_sheet7
# Out:
#     ЭХС  ТГ  НЭЖК  СХ  ФЛ  здоров(1)\болен(0)
# 0    18  22    40   9   9                   0
# 1    13  28    35  11  10                   0
# 2    11  22    41  15   9                   0
# 3    16  17    47   8   9                   0
# 4    17  38    11  18  14                   0
# ..  ...  ..   ...  ..  ..                 ...
# 79   16  25    31  18   8                   1
# 80   18  15    32  16  16                   1
# 81   11  33    28  13  12                   1
# 82   17  24    30  14  12                   1
# 83   16  25    33  10  13                   1
#
# [84 rows x 6 columns]

# %%
x = df_sheet7.drop("здоров(1)\болен(0)", axis = 1)
y = df_sheet7["здоров(1)\болен(0)"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y)

# %%
clf = RandomForestClassifier(n_estimators=150,random_state = 42,class_weight= {0: 1, 1: 8},max_depth = 3)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
accuracy_score(y_pred, y_test)
print(f"Accuracy:{accuracy_score(y_test, y_pred):.3f}")
print(f"Precision:{precision_score(y_test, y_pred):.3f}")
print(f"Recall:  {recall_score(y_test, y_pred):.3f}")
print(f"F1-score: {f1_score(y_test, y_pred):.3f}")
# print(f"ROC-AUC:{roc_auc_score(y_test, y_proba):.3f}")
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy:0.808
# Precision:0.000
# Recall:  0.000
# F1-score: 0.000
#
# Confusion Matrix:
#  [[21  1]
#  [ 4  0]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89        22
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.81        26
#    macro avg       0.42      0.48      0.45        26
# weighted avg       0.71      0.81      0.76        26

# %%
from sklearn.model_selection import cross_val_score


scores_f1 = cross_val_score(clf, x, y, cv=5, scoring='f1')

print(f"F1-результаты по фолдам: {scores_f1}")
print(f"Средний F1: {scores_f1.mean():.2f}")
# Out:
# F1-результаты по фолдам: [0.         0.4        0.57142857 0.         0.        ]
# Средний F1: 0.19

# %%
from sklearn.ensemble import GradientBoostingClassifier

clf = GradientBoostingClassifier(
    n_estimators=120,
    max_depth=3,
    random_state=42
)

# Создаем веса для каждой строки обучающей выборки
weights = y_train.map({0:1, 1:6})

clf.fit(x_train, y_train, sample_weight=weights)
y_pred = clf.predict(x_test)
accuracy_score(y_pred, y_test)
# Out:
# 0.8461538461538461

# %%
print(f"Accuracy:{accuracy_score(y_test, y_pred):.3f}")
print(f"Precision:{precision_score(y_test, y_pred):.3f}")
print(f"Recall:  {recall_score(y_test, y_pred):.3f}")
print(f"F1-score: {f1_score(y_test, y_pred):.3f}")
# print(f"ROC-AUC:{roc_auc_score(y_test, y_proba):.3f}")
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy:0.846
# Precision:0.000
# Recall:  0.000
# F1-score: 0.000
#
# Confusion Matrix:
#  [[22  0]
#  [ 4  0]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        22
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.85        26
#    macro avg       0.42      0.50      0.46        26
# weighted avg       0.72      0.85      0.78        26
# c:\Users\a.v.nasirov\.conda\envs\UDGU_project\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %%
from sklearn.model_selection import cross_val_score


scores_f1 = cross_val_score(clf, x, y, cv=5, scoring='f1')

print(f"F1-результаты по фолдам: {scores_f1}")
print(f"Средний F1: {scores_f1.mean():.2f}")
# Out:
# F1-результаты по фолдам: [0.         0.66666667 0.8        0.         0.        ]
# Средний F1: 0.29
