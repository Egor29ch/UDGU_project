# %%
import numpy as np
import pandas as pd
import warnings
import graphviz
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns

from sklearn import datasets
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, export_graphviz
from sklearn.model_selection import  train_test_split
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, classification_report
)

# %%
df_biochemistry = pd.read_excel(r"C:\Users\a.v.nasirov\Desktop\UDGU_project\random_tree_Tremor\Vse_dannye_BP_Tremor_1_unian_data.xlsx",sheet_name="БИОХИМИЯ")

# %%
df_biochemistry = df_biochemistry.drop("ФИО",axis=1)
df_biochemistry = df_biochemistry.drop("№",axis=1)

# %%
df_biochemistry
# Out:
#     ПОЛ в плазме  ПОЛ в мембр. Эритроцитов  Лактат  Глюкоза  Общий белок  \
# 0           2.05                 28.205128     7.6      8.0         41.5
# 1           3.58                 25.641026     7.6      4.7         65.0
# 2           1.03                 25.641026     5.2      6.0         44.1
# 3           2.05                 25.641026     8.4     12.7         52.0
# 4           1.53                 35.897436     8.4      5.6         41.5
# ..           ...                       ...     ...      ...          ...
# 79          1.60                  5.800000    74.0      6.7          2.3
# 80          0.80                  5.400000    70.0      5.6          2.0
# 81          2.00                  5.800000    77.0      7.7          5.3
# 82          0.80                  4.600000    77.0      6.7          3.8
# 83          0.80                  5.400000    74.0      6.7          3.3
#
#     Мочевина    Кортизол     Зонулин  Холестерин  здоров(1)\болен(0)
# ...

# %%
x = df_biochemistry.drop("здоров(1)\болен(0)", axis = 1)
y = df_biochemistry["здоров(1)\болен(0)"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y)

# %%
clf = RandomForestClassifier(n_estimators=150,random_state = 42,class_weight= {0: 1, 1: 8},max_depth = 2)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
accuracy_score(y_pred, y_test)
print(f"Accuracy:{accuracy_score(y_test, y_pred):.3f}")
print(f"Precision:{precision_score(y_test, y_pred):.3f}")
print(f"Recall:  {recall_score(y_test, y_pred):.3f}")
print(f"F1-score: {f1_score(y_test, y_pred):.3f}")
# print(f"ROC-AUC:{roc_auc_score(y_test, y_proba):.3f}")
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy:0.923
# Precision:1.000
# Recall:  0.600
# F1-score: 0.750
#
# Confusion Matrix:
#  [[21  0]
#  [ 2  3]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        21
#            1       1.00      0.60      0.75         5
#
#     accuracy                           0.92        26
#    macro avg       0.96      0.80      0.85        26
# weighted avg       0.93      0.92      0.92        26

# %%
from sklearn.model_selection import cross_val_score


scores_f1 = cross_val_score(clf, x, y, cv=5, scoring='f1')

print(f"F1-результаты по фолдам: {scores_f1}")
print(f"Средний F1: {scores_f1.mean():.2f}")
# Out:
# F1-результаты по фолдам: [0.8   1.    0.8   0.8   0.375]
# Средний F1: 0.76

# %%
from sklearn.ensemble import GradientBoostingClassifier

clf = GradientBoostingClassifier(
    n_estimators=120,
    max_depth=2,
    random_state=42
)

# Создаем веса для каждой строки обучающей выборки
weights = y_train.map({0:1, 1:6})

clf.fit(x_train, y_train, sample_weight=weights)
y_pred = clf.predict(x_test)
accuracy_score(y_pred, y_test)
# Out:
# 0.9230769230769231

# %%
print(f"Accuracy:{accuracy_score(y_test, y_pred):.3f}")
print(f"Precision:{precision_score(y_test, y_pred):.3f}")
print(f"Recall:  {recall_score(y_test, y_pred):.3f}")
print(f"F1-score: {f1_score(y_test, y_pred):.3f}")
# print(f"ROC-AUC:{roc_auc_score(y_test, y_proba):.3f}")
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy:0.923
# Precision:1.000
# Recall:  0.600
# F1-score: 0.750
#
# Confusion Matrix:
#  [[21  0]
#  [ 2  3]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        21
#            1       1.00      0.60      0.75         5
#
#     accuracy                           0.92        26
#    macro avg       0.96      0.80      0.85        26
# weighted avg       0.93      0.92      0.92        26

# %%
from sklearn.model_selection import cross_val_score


scores_f1 = cross_val_score(clf, x, y, cv=5, scoring='f1')

print(f"F1-результаты по фолдам: {scores_f1}")
print(f"Средний F1: {scores_f1.mean():.2f}")
# Out:
# F1-результаты по фолдам: [0.5   1.    0.8   0.8   0.375]
# Средний F1: 0.69
