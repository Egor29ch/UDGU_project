# %%
import numpy as np
import pandas as pd
import warnings
import graphviz
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns

from sklearn import datasets
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, export_graphviz
from sklearn.model_selection import  train_test_split
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, classification_report
)

# %%
df_red_blood_cells = pd.read_excel(r"C:\Users\a.v.nasirov\Desktop\UDGU_project\random_tree_Tremor\Vse_dannye_BP_Tremor_1_unian_data.xlsx",sheet_name="ФРАКЦИИ эритр.")

# %%
df_red_blood_cells = df_red_blood_cells.drop("ФИО",axis=1)
df_red_blood_cells = df_red_blood_cells.drop("№",axis=1)

# %%
df_red_blood_cells
# Out:
#        ФЛ     СХ    СЖК     ТГ     ЭХ  здоров(1)\болен(0)
# 0   10.38  23.16  15.53  21.32  29.61                   0
# 1    9.90  20.26  18.50  26.43  24.91                   0
# 2   14.28  19.04  23.00  23.00  23.00                   0
# 3    8.10  19.40  15.90  30.89  25.73                   0
# 4   11.06  21.05  17.61  26.22  24.06                   0
# ..    ...    ...    ...    ...    ...                 ...
# 63   9.90  17.00  22.60  21.70  28.70                   1
# 64   7.70  17.60  20.20  27.20  27.00                   1
# 65   5.90  15.00  22.30  27.60  29.10                   1
# 66   7.20  19.10  19.60  27.50  26.60                   1
# 67   9.10  23.20  27.50  34.50  26.60                   1
#
# [68 rows x 6 columns]

# %%
x = df_red_blood_cells.drop("здоров(1)\болен(0)", axis = 1)
y = df_red_blood_cells["здоров(1)\болен(0)"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y)

# %%
clf = RandomForestClassifier(n_estimators=150,random_state = 42,class_weight= {0: 1, 1: 8},max_depth = 2)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
accuracy_score(y_pred, y_test)
print(f"Accuracy:{accuracy_score(y_test, y_pred):.3f}")
print(f"Precision:{precision_score(y_test, y_pred):.3f}")
print(f"Recall:  {recall_score(y_test, y_pred):.3f}")
print(f"F1-score: {f1_score(y_test, y_pred):.3f}")
# print(f"ROC-AUC:{roc_auc_score(y_test, y_proba):.3f}")
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy:0.857
# Precision:0.500
# Recall:  0.667
# F1-score: 0.571
#
# Confusion Matrix:
#  [[16  2]
#  [ 1  2]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91        18
#            1       0.50      0.67      0.57         3
#
#     accuracy                           0.86        21
#    macro avg       0.72      0.78      0.74        21
# weighted avg       0.88      0.86      0.87        21

# %%
from sklearn.model_selection import cross_val_score


scores_f1 = cross_val_score(clf, x, y, cv=5, scoring='f1')

print(f"F1-результаты по фолдам: {scores_f1}")
print(f"Средний F1: {scores_f1.mean():.2f}")
# Out:
# F1-результаты по фолдам: [0.66666667 0.8        0.75       0.57142857 0.8       ]
# Средний F1: 0.72

# %%
from sklearn.ensemble import GradientBoostingClassifier

clf = GradientBoostingClassifier(
    n_estimators=120,
    max_depth=3,
    random_state=42
)

# Создаем веса для каждой строки обучающей выборки
weights = y_train.map({0:1, 1:6})

clf.fit(x_train, y_train, sample_weight=weights)
y_pred = clf.predict(x_test)
accuracy_score(y_pred, y_test)
# Out:
# 0.8571428571428571

# %%
print(f"Accuracy:{accuracy_score(y_test, y_pred):.3f}")
print(f"Precision:{precision_score(y_test, y_pred):.3f}")
print(f"Recall:  {recall_score(y_test, y_pred):.3f}")
print(f"F1-score: {f1_score(y_test, y_pred):.3f}")
# print(f"ROC-AUC:{roc_auc_score(y_test, y_proba):.3f}")
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy:0.857
# Precision:0.500
# Recall:  0.667
# F1-score: 0.571
#
# Confusion Matrix:
#  [[16  2]
#  [ 1  2]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91        18
#            1       0.50      0.67      0.57         3
#
#     accuracy                           0.86        21
#    macro avg       0.72      0.78      0.74        21
# weighted avg       0.88      0.86      0.87        21

# %%
from sklearn.model_selection import cross_val_score


scores_f1 = cross_val_score(clf, x, y, cv=5, scoring='f1')

print(f"F1-результаты по фолдам: {scores_f1}")
print(f"Средний F1: {scores_f1.mean():.2f}")
# Out:
# F1-результаты по фолдам: [1.         1.         0.85714286 0.66666667 1.        ]
# Средний F1: 0.90
